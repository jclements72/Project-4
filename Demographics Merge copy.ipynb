# %%
import numpy as np
import pandas as pd
from pathlib import Path

# %%
# Read the CSV file from the Resources folder into a Pandas DataFrame
income_df = pd.read_csv(
    "Demographics_Vermont_Counties_Income_Median_Household_Income_(Both_Sexes_-_2017_to_2021)_2017_-_2021.csv")
income_df.dropna(how='all', axis=1, inplace=True)

uninsured_df = pd.read_csv(
    "Demographics_Vermont_Counties_Uninsured_Unemployed_(Both_Sexes_-_Ages_16+_-_2017_to_2021)_2017_-_2021.csv")
uninsured_df.dropna(how='all', axis=1, inplace=True)

poverty_white_df = pd.read_csv(
    "Demographics_Vermont_Counties_Poverty_White_(Both_Sexes_-_2017_to_2021)_2017_-_2021.csv")
poverty_white_df.dropna(how='all', axis=1, inplace=True)

poverty_black_df = pd.read_csv(
    "Demographics_Vermont_Counties_Poverty_Black_(Both_Sexes_-_2017_to_2021)_2017_-_2021.csv")
poverty_black_df.dropna(how='all', axis=1, inplace=True)

poverty_asian_df = pd.read_csv(
    "Demographics_Vermont_Counties_Poverty_Asian_Pacific_Islander_(Both_Sexes_-_2017_to_2021)_2017_-_2021.csv")
poverty_asian_df.dropna(how='all', axis=1, inplace=True)

poverty_foreign_born_df = pd.read_csv(
    "Demographics_Vermont_Counties_Poverty_Foreign_Born_(Both_Sexes_-_2017_to_2021)_2017_-_2021.csv")
poverty_foreign_born_df.dropna(how='all', axis=1, inplace=True)

poverty_native_df = pd.read_csv(
    "Demographics_Vermont_Counties_Poverty_American_Indian_Alaska_Native_(Both_Sexes_-_2017_to_2021)_2017_-_2021.csv")
poverty_native_df.dropna(how='all', axis=1, inplace=True)

poverty_hispanic_df = pd.read_csv(
    "Demographics_Vermont_Counties_Poverty_Hispanic_(Both_Sexes_-_2017_to_2021)_2017_-_2021.csv")
poverty_hispanic_df.dropna(how='all', axis=1, inplace=True)

poverty_non_hispanic_df = pd.read_csv(
    "Demographics_Vermont_Counties_Poverty_Non-Hispanic_(Origin_Recode_(Both_Sexes_-_2017_to_2021)_2017_-_2021.csv")
poverty_non_hispanic_df.dropna(how='all', axis=1, inplace=True)

poverty_white_df.head()
# Out:
#        Demographics  Vermont Counties  Poverty
# 0              Area       County FIPS  Percent
# 1   Orange, Vermont             50017     95.4
# 2    Essex, Vermont             50009     95.4
# 3  Orleans, Vermont             50019     95.3
# 4  Rutland, Vermont             50021     95.1

# %%
poverty_white_df.columns = ["Demographics", "Vermont Counties", "White Poverty %"]
poverty_black_df.columns = ["Demographics", "Vermont Counties", "Black Poverty %"]
poverty_asian_df.columns = ["Demographics", "Vermont Counties", "Asian Poverty %"]
poverty_foreign_born_df.columns = ["Demographics", "Vermont Counties", "Foreign Poverty %"]
poverty_native_df.columns = ["Demographics", "Vermont Counties", "Native Poverty %"]
poverty_hispanic_df.columns = ["Demographics", "Vermont Counties", "Hispanic Poverty %"]
poverty_non_hispanic_df.columns = ["Demographics", "Vermont Counties", "Non Hispanic Poverty %"]

poverty_asian_df.head()
# Out:
#           Demographics Vermont Counties Asian Poverty %
# 0                 Area      County FIPS         Percent
# 1  Chittenden, Vermont            50007             4.0
# 2     Addison, Vermont            50001             2.1
# 3  Bennington, Vermont            50003             1.3
# 4     Windham, Vermont            50025             1.2

# %%
income_df.head()
# Out:
#           Demographics  Vermont Counties   Income
# 0                 Area       County FIPS  Dollars
# 1  Grand Isle, Vermont             50013    85154
# 2  Chittenden, Vermont             50007    81957
# 3     Addison, Vermont             50001    77978
# 4  Washington, Vermont             50023    70128

# %%
df_list = [income_df,uninsured_df,poverty_white_df,poverty_black_df,poverty_asian_df,poverty_foreign_born_df,poverty_native_df,
            poverty_hispanic_df,poverty_non_hispanic_df,]

# %%
from functools import reduce

df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Demographics'],
                                            how='outer'), df_list)
df_merged.to_csv('Vermont_demo', encoding='utf-8')

df_merged.head()
# Out:
# C:\Users\sholl\AppData\Local\Temp\ipykernel_7488\1611776612.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Vermont Counties_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Demographics'],
# C:\Users\sholl\AppData\Local\Temp\ipykernel_7488\1611776612.py:3: FutureWarning: Passing 'suffixes' which cause duplicate columns {'Vermont Counties_x'} in the result is deprecated and will raise a MergeError in a future version.
#   df_merged = reduce(lambda  left,right: pd.merge(left,right,on=['Demographics'],
#           Demographics  Vermont Counties_x   Income  Vermont Counties_y  \
# 0                 Area         County FIPS  Dollars         County FIPS
# 1  Grand Isle, Vermont               50013    85154               50013
# 2  Chittenden, Vermont               50007    81957               50007
# ...
